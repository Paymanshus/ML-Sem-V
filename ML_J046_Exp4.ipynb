# %% [markdown]
# <a href="https://colab.research.google.com/github/Paymanshus/ML-Sem-V/blob/master/ML_J046_Exp4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_excel('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/Canada.xlsx',
                       sheet_name='Canada by Citizenship',
                       skiprows=range(20),
                       skipfooter=2
                      )

# %%
df.head()
# Out:
#          Type    Coverage          OdName  AREA  ...  2010  2011  2012  2013
# 0  Immigrants  Foreigners     Afghanistan   935  ...  1758  2203  2635  2004
# 1  Immigrants  Foreigners         Albania   908  ...   561   539   620   603
# 2  Immigrants  Foreigners         Algeria   903  ...  4752  4325  3774  4331
# 3  Immigrants  Foreigners  American Samoa   909  ...     0     0     0     0
# 4  Immigrants  Foreigners         Andorra   908  ...     0     0     1     1
#
# [5 rows x 43 columns]

# %%
df.shape
# Out:
# (195, 43)

# %%
df.rename(columns={'OdName':'Country','AreaName':'Continent','RegName':'Continent-region','DevName':'Development-status'}, inplace=True)

df.set_index('Country', inplace=True)

df['Total_count']=df.sum(axis='columns')

# %%
years = list(map(str,range(1984, 2014)))
years
# Out:
# ['1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013']

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df_continents = df.groupby('Continent', axis='index').sum()
df_continents
# Out:
#                                   AREA     REG  ...    2013  Total_count
# Continent                                       ...
# Africa                           48762   49242  ...   38543       765660
# Asia                             45815  109147  ...  155075      3516953
# Europe                           39044   39754  ...   28691      1528488
# Latin America and the Caribbean  29832   30395  ...   24950       855141
# Northern America                  1810    1810  ...    8503       246564
# Oceania                          12726   13210  ...    1775        93736
#
# [6 rows x 38 columns]

# %% [markdown]
# ###Pie Chart

# %%
explodelist = [0.1,0.2,0,0,0,0.1]

df_continents['Total_count'].plot(
    kind='pie',
    figsize=(10,10),
    startangle=90,
    autopct='%1.1f%%',
    shadow=False,
    labels=None,
    explode=explodelist
)

plt.title('Immigration from 1980-2013 by continents')
plt.axis('equal') #pie chart looks like a circle
plt.legend(labels=df_continents.index, loc='upper left')
plt.show()

# %% [markdown]
# Pie chart of development status

# %%
colorlist = ['gold', 'lightgreen']
explodelist = [0,0.1]


df_devstatus['Total_count'].plot(
    kind='pie',
    figsize=(15,15),
    startangle=90,
    autopct='%1.1f%%',
    shadow=False,
    labels=None,
    colors=colorlist,
    explode=explodelist
)

plt.title('Immigration from 1980-2013 by developing status')
plt.axis('equal') #pie chart looks like a circle
plt.legend(labels=df_devstatus.index, loc='upper left')
plt.show()
